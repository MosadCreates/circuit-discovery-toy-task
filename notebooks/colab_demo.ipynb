# %% [markdown]
# # Circuit Discovery on a Toy Task
# ## Colab Demo
#
# This notebook runs the full pipeline: train a small transformer on modular addition,
# then reverse-engineer its circuit using Fourier analysis, activation patching, and ablation.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)]
#
# **Estimated runtime:** ~45 min on T4 GPU

# %%
# !git clone https://github.com/yourusername/circuit-discovery-toy-task
# %cd circuit-discovery-toy-task
# !pip install -r requirements.txt

# %%
# !python src/training/train.py --config configs/training/default.yaml

# %%
# !python src/analysis/attention_patterns.py
# !python src/analysis/fourier.py
# !python src/analysis/neuron_analysis.py
# !python src/analysis/direct_logit_attribution.py
# !python src/analysis/minimal_circuit.py

# %% [markdown]
# ## Results
#
# Figures are saved to `results/figures/`. Key findings:
# - Fourier spectrum: top-5 frequencies explain >80% variance
# - 2 heads + 15 neurons = 95% of full model accuracy
# - Full writeup at `docs/writeup.md`
